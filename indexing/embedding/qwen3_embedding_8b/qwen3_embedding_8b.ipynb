# %%
from typing import List, Iterable, Union

from langchain_core.embeddings import Embeddings

import torch
import torch.nn.functional as F

from torch import Tensor
from transformers import AutoTokenizer, AutoModel, BitsAndBytesConfig

def _last_token_pool(last_hidden_states: Tensor,
                 attention_mask: Tensor) -> Tensor:
    left_padding = (attention_mask[:, -1].sum() == attention_mask.shape[0])
    if left_padding:
        return last_hidden_states[:, -1]
    else:
        sequence_lengths = attention_mask.sum(dim=1) - 1
        batch_size = last_hidden_states.shape[0]
        return last_hidden_states[torch.arange(batch_size, device=last_hidden_states.device), sequence_lengths]

class MyEmbeddings(Embeddings):
    def __init__(
        self,
        model: str = "Qwen/Qwen3-Embedding-8B",
        *,
        max_length: int = 8192,
        device = None
    ):
        self.model_name = model
        self.max_length = max_length

        self._tokenizer = tokenizer = AutoTokenizer.from_pretrained(self.model_name, padding_side='left')

        bnb_config = BitsAndBytesConfig(load_in_4bit=True)
        self._model = AutoModel.from_pretrained(self.model_name,quantization_config=bnb_config,).eval()

        if device is None:
            if torch.cuda.is_available():
                device = "cuda"
            elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
                device = "mps"
            else:
                device = "cpu"
        self._device = torch.device(device)
        self._model.to(self._device)

    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        return self._embed_texts(texts)

    def embed_query(self, text: str) -> List[float]:
        return self._embed_texts([text])[0]

    @torch.inference_mode()
    def _embed_texts(self, texts: Union[List[str], Iterable[str]]) -> List[List[float]]:
        batch_dict = self._tokenizer(
            texts,
            padding=True,
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt",
        )
        batch_dict.to(self._device)
        outputs = self._model(**batch_dict)
        

        embeddings = _last_token_pool(outputs.last_hidden_state, batch_dict['attention_mask'])

        out = embeddings.tolist()
        return out

# %%
from langchain_huggingface.embeddings import HuggingFaceEndpointEmbeddings

my_embeddings = MyEmbeddings()
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import json
from langchain_core.documents import Document

output_file = "../../../data/chunked/markdown_header_text_splitter/markdown_header_text_splitter.jsonl"

docs = []
with open(output_file, "r", encoding="utf-8") as f:
    for line in f:
        d = json.loads(line) 
        docs.append(Document(**d))

# %%
from langchain_chroma import Chroma

DB_PATH = "../../../data/embedded/chroma_db"

chroma_db = Chroma(
    collection_name="samsung_quarterly_report",
    embedding_function=my_embeddings,
    persist_directory=DB_PATH,
)

batch_size = 1
for i in range(0, len(docs), batch_size):
    batch = docs[i : i + batch_size]
    chroma_db.add_documents(batch)
    print(f"Batch {i // batch_size + 1} ({len(batch)} docs) 추가 완료")

print("모든 문서 임베딩 완료 및 저장 완료")
# Out:
# Batch 1 (1 docs) 추가 완료
# Batch 2 (1 docs) 추가 완료
# Batch 3 (1 docs) 추가 완료
# Batch 4 (1 docs) 추가 완료
# Batch 5 (1 docs) 추가 완료
# Batch 6 (1 docs) 추가 완료
# Batch 7 (1 docs) 추가 완료
# Batch 8 (1 docs) 추가 완료
# Batch 9 (1 docs) 추가 완료
# Batch 10 (1 docs) 추가 완료
# Batch 11 (1 docs) 추가 완료
# Batch 12 (1 docs) 추가 완료
# Batch 13 (1 docs) 추가 완료
# Batch 14 (1 docs) 추가 완료
# Batch 15 (1 docs) 추가 완료
# Batch 16 (1 docs) 추가 완료
# Batch 17 (1 docs) 추가 완료
# Batch 18 (1 docs) 추가 완료
# Batch 19 (1 docs) 추가 완료
# Batch 20 (1 docs) 추가 완료
# Batch 21 (1 docs) 추가 완료
# Batch 22 (1 docs) 추가 완료
# Batch 23 (1 docs) 추가 완료
# Batch 24 (1 docs) 추가 완료
# Batch 25 (1 docs) 추가 완료
# Batch 26 (1 docs) 추가 완료
# Batch 27 (1 docs) 추가 완료
# Batch 28 (1 docs) 추가 완료
# Batch 29 (1 docs) 추가 완료
# Batch 30 (1 docs) 추가 완료
# Batch 31 (1 docs) 추가 완료
# Batch 32 (1 docs) 추가 완료
# Batch 33 (1 docs) 추가 완료
# Batch 34 (1 docs) 추가 완료
# Batch 35 (1 docs) 추가 완료
# Batch 36 (1 docs) 추가 완료
# Batch 37 (1 docs) 추가 완료
# Batch 38 (1 docs) 추가 완료
# Batch 39 (1 docs) 추가 완료
# Batch 40 (1 docs) 추가 완료
# Batch 41 (1 docs) 추가 완료
# Batch 42 (1 docs) 추가 완료
# Batch 43 (1 docs) 추가 완료
# Batch 44 (1 docs) 추가 완료
# Batch 45 (1 docs) 추가 완료
# Batch 46 (1 docs) 추가 완료
# Batch 47 (1 docs) 추가 완료
# Batch 48 (1 docs) 추가 완료
# Batch 49 (1 docs) 추가 완료
# Batch 50 (1 docs) 추가 완료
# Batch 51 (1 docs) 추가 완료
# Batch 52 (1 docs) 추가 완료
# Batch 53 (1 docs) 추가 완료
# Batch 54 (1 docs) 추가 완료
# Batch 55 (1 docs) 추가 완료
# Batch 56 (1 docs) 추가 완료
# Batch 57 (1 docs) 추가 완료
# Batch 58 (1 docs) 추가 완료
# Batch 59 (1 docs) 추가 완료
# Batch 60 (1 docs) 추가 완료
# Batch 61 (1 docs) 추가 완료
# Batch 62 (1 docs) 추가 완료
# Batch 63 (1 docs) 추가 완료
# Batch 64 (1 docs) 추가 완료
# Batch 65 (1 docs) 추가 완료
# Batch 66 (1 docs) 추가 완료
# Batch 67 (1 docs) 추가 완료
# Batch 68 (1 docs) 추가 완료
# Batch 69 (1 docs) 추가 완료
# Batch 70 (1 docs) 추가 완료
# Batch 71 (1 docs) 추가 완료
# Batch 72 (1 docs) 추가 완료
# Batch 73 (1 docs) 추가 완료
# Batch 74 (1 docs) 추가 완료
# Batch 75 (1 docs) 추가 완료
# Batch 76 (1 docs) 추가 완료
# Batch 77 (1 docs) 추가 완료
# Batch 78 (1 docs) 추가 완료
# Batch 79 (1 docs) 추가 완료
# Batch 80 (1 docs) 추가 완료
# Batch 81 (1 docs) 추가 완료
# Batch 82 (1 docs) 추가 완료
# Batch 83 (1 docs) 추가 완료
# Batch 84 (1 docs) 추가 완료
# Batch 85 (1 docs) 추가 완료
# Batch 86 (1 docs) 추가 완료
# Batch 87 (1 docs) 추가 완료
# Batch 88 (1 docs) 추가 완료
# Batch 89 (1 docs) 추가 완료
# Batch 90 (1 docs) 추가 완료
# Batch 91 (1 docs) 추가 완료
# Batch 92 (1 docs) 추가 완료
# Batch 93 (1 docs) 추가 완료
# Batch 94 (1 docs) 추가 완료
# Batch 95 (1 docs) 추가 완료
# Batch 96 (1 docs) 추가 완료
# Batch 97 (1 docs) 추가 완료
# Batch 98 (1 docs) 추가 완료
# Batch 99 (1 docs) 추가 완료
# Batch 100 (1 docs) 추가 완료
# Batch 101 (1 docs) 추가 완료
# Batch 102 (1 docs) 추가 완료
# Batch 103 (1 docs) 추가 완료
# Batch 104 (1 docs) 추가 완료
# Batch 105 (1 docs) 추가 완료
# Batch 106 (1 docs) 추가 완료
# Batch 107 (1 docs) 추가 완료
# Batch 108 (1 docs) 추가 완료
# Batch 109 (1 docs) 추가 완료
# Batch 110 (1 docs) 추가 완료
# Batch 111 (1 docs) 추가 완료
# Batch 112 (1 docs) 추가 완료
# Batch 113 (1 docs) 추가 완료
# Batch 114 (1 docs) 추가 완료
# Batch 115 (1 docs) 추가 완료
# Batch 116 (1 docs) 추가 완료
# Batch 117 (1 docs) 추가 완료
# Batch 118 (1 docs) 추가 완료
# Batch 119 (1 docs) 추가 완료
# Batch 120 (1 docs) 추가 완료
# Batch 121 (1 docs) 추가 완료
# Batch 122 (1 docs) 추가 완료
# Batch 123 (1 docs) 추가 완료
# Batch 124 (1 docs) 추가 완료
# Batch 125 (1 docs) 추가 완료
# Batch 126 (1 docs) 추가 완료
# Batch 127 (1 docs) 추가 완료
# Batch 128 (1 docs) 추가 완료
# Batch 129 (1 docs) 추가 완료
# Batch 130 (1 docs) 추가 완료
# Batch 131 (1 docs) 추가 완료
# Batch 132 (1 docs) 추가 완료
# Batch 133 (1 docs) 추가 완료
# Batch 134 (1 docs) 추가 완료
# Batch 135 (1 docs) 추가 완료
# Batch 136 (1 docs) 추가 완료
# Batch 137 (1 docs) 추가 완료
# Batch 138 (1 docs) 추가 완료
# Batch 139 (1 docs) 추가 완료
# Batch 140 (1 docs) 추가 완료
# Batch 141 (1 docs) 추가 완료
# Batch 142 (1 docs) 추가 완료
# Batch 143 (1 docs) 추가 완료
# Batch 144 (1 docs) 추가 완료
# Batch 145 (1 docs) 추가 완료
# Batch 146 (1 docs) 추가 완료
# Batch 147 (1 docs) 추가 완료
# Batch 148 (1 docs) 추가 완료
# Batch 149 (1 docs) 추가 완료
# Batch 150 (1 docs) 추가 완료
# Batch 151 (1 docs) 추가 완료
# Batch 152 (1 docs) 추가 완료
# Batch 153 (1 docs) 추가 완료
# Batch 154 (1 docs) 추가 완료
# Batch 155 (1 docs) 추가 완료
# Batch 156 (1 docs) 추가 완료
# Batch 157 (1 docs) 추가 완료
# Batch 158 (1 docs) 추가 완료
# Batch 159 (1 docs) 추가 완료
# Batch 160 (1 docs) 추가 완료
# Batch 161 (1 docs) 추가 완료
# Batch 162 (1 docs) 추가 완료
# Batch 163 (1 docs) 추가 완료
# Batch 164 (1 docs) 추가 완료
# Batch 165 (1 docs) 추가 완료
# Batch 166 (1 docs) 추가 완료
# Batch 167 (1 docs) 추가 완료
# Batch 168 (1 docs) 추가 완료
# Batch 169 (1 docs) 추가 완료
# Batch 170 (1 docs) 추가 완료
# Batch 171 (1 docs) 추가 완료
# Batch 172 (1 docs) 추가 완료
# Batch 173 (1 docs) 추가 완료
# Batch 174 (1 docs) 추가 완료
# Batch 175 (1 docs) 추가 완료
# Batch 176 (1 docs) 추가 완료
# Batch 177 (1 docs) 추가 완료
# Batch 178 (1 docs) 추가 완료
# Batch 179 (1 docs) 추가 완료
# Batch 180 (1 docs) 추가 완료
# Batch 181 (1 docs) 추가 완료
# Batch 182 (1 docs) 추가 완료
# Batch 183 (1 docs) 추가 완료
# Batch 184 (1 docs) 추가 완료
# Batch 185 (1 docs) 추가 완료
# Batch 186 (1 docs) 추가 완료
# Batch 187 (1 docs) 추가 완료
# Batch 188 (1 docs) 추가 완료
# Batch 189 (1 docs) 추가 완료
# Batch 190 (1 docs) 추가 완료
# Batch 191 (1 docs) 추가 완료
# Batch 192 (1 docs) 추가 완료
# Batch 193 (1 docs) 추가 완료
# Batch 194 (1 docs) 추가 완료
# Batch 195 (1 docs) 추가 완료
# Batch 196 (1 docs) 추가 완료
# Batch 197 (1 docs) 추가 완료
# Batch 198 (1 docs) 추가 완료
# Batch 199 (1 docs) 추가 완료
# Batch 200 (1 docs) 추가 완료
# Batch 201 (1 docs) 추가 완료
# Batch 202 (1 docs) 추가 완료
# Batch 203 (1 docs) 추가 완료
# Batch 204 (1 docs) 추가 완료
# Batch 205 (1 docs) 추가 완료
# Batch 206 (1 docs) 추가 완료
# Batch 207 (1 docs) 추가 완료
# Batch 208 (1 docs) 추가 완료
# Batch 209 (1 docs) 추가 완료
# Batch 210 (1 docs) 추가 완료
# Batch 211 (1 docs) 추가 완료
# Batch 212 (1 docs) 추가 완료
# Batch 213 (1 docs) 추가 완료
# Batch 214 (1 docs) 추가 완료
# Batch 215 (1 docs) 추가 완료
# Batch 216 (1 docs) 추가 완료
# Batch 217 (1 docs) 추가 완료
# Batch 218 (1 docs) 추가 완료
# Batch 219 (1 docs) 추가 완료
# Batch 220 (1 docs) 추가 완료
# Batch 221 (1 docs) 추가 완료
# Batch 222 (1 docs) 추가 완료
# Batch 223 (1 docs) 추가 완료
# Batch 224 (1 docs) 추가 완료
# Batch 225 (1 docs) 추가 완료
# Batch 226 (1 docs) 추가 완료
# Batch 227 (1 docs) 추가 완료
# Batch 228 (1 docs) 추가 완료
# Batch 229 (1 docs) 추가 완료
# Batch 230 (1 docs) 추가 완료
# Batch 231 (1 docs) 추가 완료
# Batch 232 (1 docs) 추가 완료
# Batch 233 (1 docs) 추가 완료
# Batch 234 (1 docs) 추가 완료
# Batch 235 (1 docs) 추가 완료
# Batch 236 (1 docs) 추가 완료
# Batch 237 (1 docs) 추가 완료
# Batch 238 (1 docs) 추가 완료
# Batch 239 (1 docs) 추가 완료
# Batch 240 (1 docs) 추가 완료
# Batch 241 (1 docs) 추가 완료
# Batch 242 (1 docs) 추가 완료
# Batch 243 (1 docs) 추가 완료
# Batch 244 (1 docs) 추가 완료
# Batch 245 (1 docs) 추가 완료
# Batch 246 (1 docs) 추가 완료
# Batch 247 (1 docs) 추가 완료
# Batch 248 (1 docs) 추가 완료
# Batch 249 (1 docs) 추가 완료
# Batch 250 (1 docs) 추가 완료
# Batch 251 (1 docs) 추가 완료
# Batch 252 (1 docs) 추가 완료
# Batch 253 (1 docs) 추가 완료
# Batch 254 (1 docs) 추가 완료
# Batch 255 (1 docs) 추가 완료
# Batch 256 (1 docs) 추가 완료
# Batch 257 (1 docs) 추가 완료
# Batch 258 (1 docs) 추가 완료
# Batch 259 (1 docs) 추가 완료
# Batch 260 (1 docs) 추가 완료
# Batch 261 (1 docs) 추가 완료
# Batch 262 (1 docs) 추가 완료
# Batch 263 (1 docs) 추가 완료
# Batch 264 (1 docs) 추가 완료
# Batch 265 (1 docs) 추가 완료
# Batch 266 (1 docs) 추가 완료
# Batch 267 (1 docs) 추가 완료
# Batch 268 (1 docs) 추가 완료
# Batch 269 (1 docs) 추가 완료
# Batch 270 (1 docs) 추가 완료
# Batch 271 (1 docs) 추가 완료
# Batch 272 (1 docs) 추가 완료
# Batch 273 (1 docs) 추가 완료
# Batch 274 (1 docs) 추가 완료
# Batch 275 (1 docs) 추가 완료
# Batch 276 (1 docs) 추가 완료
# Batch 277 (1 docs) 추가 완료
# Batch 278 (1 docs) 추가 완료
# Batch 279 (1 docs) 추가 완료
# Batch 280 (1 docs) 추가 완료
# Batch 281 (1 docs) 추가 완료
# Batch 282 (1 docs) 추가 완료
# Batch 283 (1 docs) 추가 완료
# Batch 284 (1 docs) 추가 완료
# Batch 285 (1 docs) 추가 완료
# Batch 286 (1 docs) 추가 완료
# Batch 287 (1 docs) 추가 완료
# Batch 288 (1 docs) 추가 완료
# Batch 289 (1 docs) 추가 완료
# Batch 290 (1 docs) 추가 완료
# Batch 291 (1 docs) 추가 완료
# Batch 292 (1 docs) 추가 완료
# Batch 293 (1 docs) 추가 완료
# Batch 294 (1 docs) 추가 완료
# Batch 295 (1 docs) 추가 완료
# Batch 296 (1 docs) 추가 완료
# Batch 297 (1 docs) 추가 완료
# Batch 298 (1 docs) 추가 완료
# Batch 299 (1 docs) 추가 완료
# Batch 300 (1 docs) 추가 완료
# Batch 301 (1 docs) 추가 완료
# Batch 302 (1 docs) 추가 완료
# Batch 303 (1 docs) 추가 완료
# Batch 304 (1 docs) 추가 완료
# Batch 305 (1 docs) 추가 완료
# Batch 306 (1 docs) 추가 완료
# Batch 307 (1 docs) 추가 완료
# Batch 308 (1 docs) 추가 완료
# Batch 309 (1 docs) 추가 완료
# Batch 310 (1 docs) 추가 완료
# Batch 311 (1 docs) 추가 완료
# Batch 312 (1 docs) 추가 완료
# Batch 313 (1 docs) 추가 완료
# Batch 314 (1 docs) 추가 완료
# Batch 315 (1 docs) 추가 완료
# Batch 316 (1 docs) 추가 완료
# Batch 317 (1 docs) 추가 완료
# Batch 318 (1 docs) 추가 완료
# Batch 319 (1 docs) 추가 완료
# Batch 320 (1 docs) 추가 완료
# Batch 321 (1 docs) 추가 완료
# Batch 322 (1 docs) 추가 완료
# Batch 323 (1 docs) 추가 완료
# Batch 324 (1 docs) 추가 완료
# Batch 325 (1 docs) 추가 완료
# Batch 326 (1 docs) 추가 완료
# Batch 327 (1 docs) 추가 완료
# Batch 328 (1 docs) 추가 완료
# Batch 329 (1 docs) 추가 완료
# Batch 330 (1 docs) 추가 완료
# Batch 331 (1 docs) 추가 완료
# Batch 332 (1 docs) 추가 완료
# Batch 333 (1 docs) 추가 완료
# Batch 334 (1 docs) 추가 완료
# Batch 335 (1 docs) 추가 완료
# Batch 336 (1 docs) 추가 완료
# Batch 337 (1 docs) 추가 완료
# Batch 338 (1 docs) 추가 완료
# Batch 339 (1 docs) 추가 완료
# Batch 340 (1 docs) 추가 완료
# Batch 341 (1 docs) 추가 완료
# Batch 342 (1 docs) 추가 완료
# Batch 343 (1 docs) 추가 완료
# Batch 344 (1 docs) 추가 완료
# Batch 345 (1 docs) 추가 완료
# Batch 346 (1 docs) 추가 완료
# Batch 347 (1 docs) 추가 완료
# Batch 348 (1 docs) 추가 완료
# Batch 349 (1 docs) 추가 완료
# Batch 350 (1 docs) 추가 완료
# Batch 351 (1 docs) 추가 완료
# Batch 352 (1 docs) 추가 완료
# Batch 353 (1 docs) 추가 완료
# Batch 354 (1 docs) 추가 완료
# Batch 355 (1 docs) 추가 완료
# Batch 356 (1 docs) 추가 완료
# Batch 357 (1 docs) 추가 완료
# Batch 358 (1 docs) 추가 완료
# Batch 359 (1 docs) 추가 완료
# Batch 360 (1 docs) 추가 완료
# Batch 361 (1 docs) 추가 완료
# Batch 362 (1 docs) 추가 완료
# Batch 363 (1 docs) 추가 완료
# Batch 364 (1 docs) 추가 완료
# Batch 365 (1 docs) 추가 완료
# Batch 366 (1 docs) 추가 완료
# Batch 367 (1 docs) 추가 완료
# Batch 368 (1 docs) 추가 완료
# Batch 369 (1 docs) 추가 완료
# Batch 370 (1 docs) 추가 완료
# Batch 371 (1 docs) 추가 완료
# Batch 372 (1 docs) 추가 완료
# Batch 373 (1 docs) 추가 완료
# Batch 374 (1 docs) 추가 완료
# Batch 375 (1 docs) 추가 완료
# Batch 376 (1 docs) 추가 완료
# Batch 377 (1 docs) 추가 완료
# Batch 378 (1 docs) 추가 완료
# Batch 379 (1 docs) 추가 완료
# Batch 380 (1 docs) 추가 완료
# Batch 381 (1 docs) 추가 완료
# Batch 382 (1 docs) 추가 완료
# Batch 383 (1 docs) 추가 완료
# Batch 384 (1 docs) 추가 완료
# Batch 385 (1 docs) 추가 완료
# Batch 386 (1 docs) 추가 완료
# Batch 387 (1 docs) 추가 완료
# Batch 388 (1 docs) 추가 완료
# Batch 389 (1 docs) 추가 완료
# Batch 390 (1 docs) 추가 완료
# Batch 391 (1 docs) 추가 완료
# Batch 392 (1 docs) 추가 완료
# Batch 393 (1 docs) 추가 완료
# Batch 394 (1 docs) 추가 완료
# Batch 395 (1 docs) 추가 완료
# Batch 396 (1 docs) 추가 완료
# Batch 397 (1 docs) 추가 완료
# Batch 398 (1 docs) 추가 완료
# Batch 399 (1 docs) 추가 완료
# Batch 400 (1 docs) 추가 완료
# Batch 401 (1 docs) 추가 완료
# Batch 402 (1 docs) 추가 완료
# Batch 403 (1 docs) 추가 완료
# Batch 404 (1 docs) 추가 완료
# Batch 405 (1 docs) 추가 완료
# Batch 406 (1 docs) 추가 완료
# Batch 407 (1 docs) 추가 완료
# Batch 408 (1 docs) 추가 완료
# Batch 409 (1 docs) 추가 완료
# Batch 410 (1 docs) 추가 완료
# Batch 411 (1 docs) 추가 완료
# Batch 412 (1 docs) 추가 완료
# Batch 413 (1 docs) 추가 완료
# Batch 414 (1 docs) 추가 완료
# Batch 415 (1 docs) 추가 완료
# Batch 416 (1 docs) 추가 완료
# Batch 417 (1 docs) 추가 완료
# Batch 418 (1 docs) 추가 완료
# Batch 419 (1 docs) 추가 완료
# Batch 420 (1 docs) 추가 완료
# Batch 421 (1 docs) 추가 완료
# Batch 422 (1 docs) 추가 완료
# Batch 423 (1 docs) 추가 완료
# Batch 424 (1 docs) 추가 완료
# Batch 425 (1 docs) 추가 완료
# Batch 426 (1 docs) 추가 완료
# Batch 427 (1 docs) 추가 완료
# Batch 428 (1 docs) 추가 완료
# Batch 429 (1 docs) 추가 완료
# Batch 430 (1 docs) 추가 완료
# Batch 431 (1 docs) 추가 완료
# Batch 432 (1 docs) 추가 완료
# Batch 433 (1 docs) 추가 완료
# Batch 434 (1 docs) 추가 완료
# Batch 435 (1 docs) 추가 완료
# Batch 436 (1 docs) 추가 완료
# Batch 437 (1 docs) 추가 완료
# Batch 438 (1 docs) 추가 완료
# Batch 439 (1 docs) 추가 완료
# Batch 440 (1 docs) 추가 완료
# Batch 441 (1 docs) 추가 완료
# Batch 442 (1 docs) 추가 완료
# Batch 443 (1 docs) 추가 완료
# Batch 444 (1 docs) 추가 완료
# Batch 445 (1 docs) 추가 완료
# Batch 446 (1 docs) 추가 완료
# Batch 447 (1 docs) 추가 완료
# Batch 448 (1 docs) 추가 완료
# Batch 449 (1 docs) 추가 완료
# Batch 450 (1 docs) 추가 완료
# Batch 451 (1 docs) 추가 완료
# Batch 452 (1 docs) 추가 완료
# Batch 453 (1 docs) 추가 완료
# Batch 454 (1 docs) 추가 완료
# Batch 455 (1 docs) 추가 완료
# Batch 456 (1 docs) 추가 완료
# Batch 457 (1 docs) 추가 완료
# Batch 458 (1 docs) 추가 완료
# Batch 459 (1 docs) 추가 완료
# Batch 460 (1 docs) 추가 완료
# Batch 461 (1 docs) 추가 완료
# Batch 462 (1 docs) 추가 완료
# Batch 463 (1 docs) 추가 완료
# Batch 464 (1 docs) 추가 완료
# Batch 465 (1 docs) 추가 완료
# Batch 466 (1 docs) 추가 완료
# Batch 467 (1 docs) 추가 완료
# Batch 468 (1 docs) 추가 완료
# Batch 469 (1 docs) 추가 완료
# Batch 470 (1 docs) 추가 완료
# Batch 471 (1 docs) 추가 완료
# Batch 472 (1 docs) 추가 완료
# Batch 473 (1 docs) 추가 완료
# Batch 474 (1 docs) 추가 완료
# Batch 475 (1 docs) 추가 완료
# Batch 476 (1 docs) 추가 완료
# Batch 477 (1 docs) 추가 완료
# Batch 478 (1 docs) 추가 완료
# Batch 479 (1 docs) 추가 완료
# Batch 480 (1 docs) 추가 완료
# Batch 481 (1 docs) 추가 완료
# Batch 482 (1 docs) 추가 완료
# Batch 483 (1 docs) 추가 완료
# Batch 484 (1 docs) 추가 완료
# Batch 485 (1 docs) 추가 완료
# Batch 486 (1 docs) 추가 완료
# Batch 487 (1 docs) 추가 완료
# Batch 488 (1 docs) 추가 완료
# Batch 489 (1 docs) 추가 완료
# Batch 490 (1 docs) 추가 완료
# Batch 491 (1 docs) 추가 완료
# Batch 492 (1 docs) 추가 완료
# Batch 493 (1 docs) 추가 완료
# Batch 494 (1 docs) 추가 완료
# Batch 495 (1 docs) 추가 완료
# Batch 496 (1 docs) 추가 완료
# Batch 497 (1 docs) 추가 완료
# Batch 498 (1 docs) 추가 완료
# Batch 499 (1 docs) 추가 완료
# Batch 500 (1 docs) 추가 완료
# Batch 501 (1 docs) 추가 완료
# Batch 502 (1 docs) 추가 완료
# Batch 503 (1 docs) 추가 완료
# Batch 504 (1 docs) 추가 완료
# Batch 505 (1 docs) 추가 완료
# Batch 506 (1 docs) 추가 완료
# Batch 507 (1 docs) 추가 완료
# Batch 508 (1 docs) 추가 완료
# Batch 509 (1 docs) 추가 완료
# Batch 510 (1 docs) 추가 완료
# Batch 511 (1 docs) 추가 완료
# Batch 512 (1 docs) 추가 완료
# Batch 513 (1 docs) 추가 완료
# Batch 514 (1 docs) 추가 완료
# Batch 515 (1 docs) 추가 완료
# Batch 516 (1 docs) 추가 완료
# Batch 517 (1 docs) 추가 완료
# Batch 518 (1 docs) 추가 완료
# Batch 519 (1 docs) 추가 완료
# Batch 520 (1 docs) 추가 완료
# Batch 521 (1 docs) 추가 완료
# Batch 522 (1 docs) 추가 완료
# Batch 523 (1 docs) 추가 완료
# Batch 524 (1 docs) 추가 완료
# Batch 525 (1 docs) 추가 완료
# Batch 526 (1 docs) 추가 완료
# Batch 527 (1 docs) 추가 완료
# Batch 528 (1 docs) 추가 완료
# Batch 529 (1 docs) 추가 완료
# Batch 530 (1 docs) 추가 완료
# Batch 531 (1 docs) 추가 완료
# Batch 532 (1 docs) 추가 완료
# Batch 533 (1 docs) 추가 완료
# Batch 534 (1 docs) 추가 완료
# Batch 535 (1 docs) 추가 완료
# Batch 536 (1 docs) 추가 완료
# Batch 537 (1 docs) 추가 완료
# Batch 538 (1 docs) 추가 완료
# Batch 539 (1 docs) 추가 완료
# Batch 540 (1 docs) 추가 완료
# Batch 541 (1 docs) 추가 완료
# Batch 542 (1 docs) 추가 완료
# Batch 543 (1 docs) 추가 완료
# Batch 544 (1 docs) 추가 완료
# Batch 545 (1 docs) 추가 완료
# Batch 546 (1 docs) 추가 완료
# Batch 547 (1 docs) 추가 완료
# Batch 548 (1 docs) 추가 완료
# Batch 549 (1 docs) 추가 완료
# Batch 550 (1 docs) 추가 완료
# Batch 551 (1 docs) 추가 완료
# Batch 552 (1 docs) 추가 완료
# Batch 553 (1 docs) 추가 완료
# Batch 554 (1 docs) 추가 완료
# Batch 555 (1 docs) 추가 완료
# Batch 556 (1 docs) 추가 완료
# Batch 557 (1 docs) 추가 완료
# Batch 558 (1 docs) 추가 완료
# Batch 559 (1 docs) 추가 완료
# Batch 560 (1 docs) 추가 완료
# Batch 561 (1 docs) 추가 완료
# Batch 562 (1 docs) 추가 완료
# Batch 563 (1 docs) 추가 완료
# Batch 564 (1 docs) 추가 완료
# Batch 565 (1 docs) 추가 완료
# Batch 566 (1 docs) 추가 완료
# Batch 567 (1 docs) 추가 완료
# Batch 568 (1 docs) 추가 완료
# Batch 569 (1 docs) 추가 완료
# Batch 570 (1 docs) 추가 완료
# Batch 571 (1 docs) 추가 완료
# Batch 572 (1 docs) 추가 완료
# Batch 573 (1 docs) 추가 완료
# Batch 574 (1 docs) 추가 완료
# Batch 575 (1 docs) 추가 완료
# Batch 576 (1 docs) 추가 완료
# Batch 577 (1 docs) 추가 완료
# Batch 578 (1 docs) 추가 완료
# Batch 579 (1 docs) 추가 완료
# Batch 580 (1 docs) 추가 완료
# Batch 581 (1 docs) 추가 완료
# Batch 582 (1 docs) 추가 완료
# Batch 583 (1 docs) 추가 완료
# Batch 584 (1 docs) 추가 완료
# Batch 585 (1 docs) 추가 완료
# Batch 586 (1 docs) 추가 완료
# Batch 587 (1 docs) 추가 완료
# Batch 588 (1 docs) 추가 완료
# Batch 589 (1 docs) 추가 완료
# Batch 590 (1 docs) 추가 완료
# Batch 591 (1 docs) 추가 완료
# Batch 592 (1 docs) 추가 완료
# Batch 593 (1 docs) 추가 완료
# Batch 594 (1 docs) 추가 완료
# Batch 595 (1 docs) 추가 완료
# Batch 596 (1 docs) 추가 완료
# Batch 597 (1 docs) 추가 완료
# Batch 598 (1 docs) 추가 완료
# Batch 599 (1 docs) 추가 완료
# Batch 600 (1 docs) 추가 완료
# Batch 601 (1 docs) 추가 완료
# Batch 602 (1 docs) 추가 완료
# Batch 603 (1 docs) 추가 완료
# Batch 604 (1 docs) 추가 완료
# Batch 605 (1 docs) 추가 완료
# Batch 606 (1 docs) 추가 완료
# Batch 607 (1 docs) 추가 완료
# Batch 608 (1 docs) 추가 완료
# Batch 609 (1 docs) 추가 완료
# Batch 610 (1 docs) 추가 완료
# Batch 611 (1 docs) 추가 완료
# Batch 612 (1 docs) 추가 완료
# Batch 613 (1 docs) 추가 완료
# Batch 614 (1 docs) 추가 완료
# Batch 615 (1 docs) 추가 완료
# Batch 616 (1 docs) 추가 완료
# Batch 617 (1 docs) 추가 완료
# Batch 618 (1 docs) 추가 완료
# Batch 619 (1 docs) 추가 완료
# Batch 620 (1 docs) 추가 완료
# Batch 621 (1 docs) 추가 완료
# Batch 622 (1 docs) 추가 완료
# Batch 623 (1 docs) 추가 완료
# Batch 624 (1 docs) 추가 완료
# Batch 625 (1 docs) 추가 완료
# Batch 626 (1 docs) 추가 완료
# Batch 627 (1 docs) 추가 완료
# Batch 628 (1 docs) 추가 완료
# Batch 629 (1 docs) 추가 완료
# Batch 630 (1 docs) 추가 완료
# Batch 631 (1 docs) 추가 완료
# Batch 632 (1 docs) 추가 완료
# Batch 633 (1 docs) 추가 완료
# Batch 634 (1 docs) 추가 완료
# Batch 635 (1 docs) 추가 완료
# Batch 636 (1 docs) 추가 완료
# Batch 637 (1 docs) 추가 완료
# Batch 638 (1 docs) 추가 완료
# Batch 639 (1 docs) 추가 완료
# Batch 640 (1 docs) 추가 완료
# Batch 641 (1 docs) 추가 완료
# Batch 642 (1 docs) 추가 완료
# Batch 643 (1 docs) 추가 완료
# Batch 644 (1 docs) 추가 완료
# Batch 645 (1 docs) 추가 완료
# Batch 646 (1 docs) 추가 완료
# Batch 647 (1 docs) 추가 완료
# Batch 648 (1 docs) 추가 완료
# Batch 649 (1 docs) 추가 완료
# Batch 650 (1 docs) 추가 완료
# Batch 651 (1 docs) 추가 완료
# Batch 652 (1 docs) 추가 완료
# Batch 653 (1 docs) 추가 완료
# Batch 654 (1 docs) 추가 완료
# Batch 655 (1 docs) 추가 완료
# Batch 656 (1 docs) 추가 완료
# Batch 657 (1 docs) 추가 완료
# Batch 658 (1 docs) 추가 완료
# Batch 659 (1 docs) 추가 완료
# Batch 660 (1 docs) 추가 완료
# Batch 661 (1 docs) 추가 완료
# Batch 662 (1 docs) 추가 완료
# Batch 663 (1 docs) 추가 완료
# Batch 664 (1 docs) 추가 완료
# Batch 665 (1 docs) 추가 완료
# Batch 666 (1 docs) 추가 완료
# Batch 667 (1 docs) 추가 완료
# Batch 668 (1 docs) 추가 완료
# Batch 669 (1 docs) 추가 완료
# Batch 670 (1 docs) 추가 완료
# Batch 671 (1 docs) 추가 완료
# Batch 672 (1 docs) 추가 완료
# Batch 673 (1 docs) 추가 완료
# Batch 674 (1 docs) 추가 완료
# Batch 675 (1 docs) 추가 완료
# Batch 676 (1 docs) 추가 완료
# Batch 677 (1 docs) 추가 완료
# Batch 678 (1 docs) 추가 완료
# Batch 679 (1 docs) 추가 완료
# Batch 680 (1 docs) 추가 완료
# Batch 681 (1 docs) 추가 완료
# Batch 682 (1 docs) 추가 완료
# Batch 683 (1 docs) 추가 완료
# Batch 684 (1 docs) 추가 완료
# Batch 685 (1 docs) 추가 완료
# Batch 686 (1 docs) 추가 완료
# Batch 687 (1 docs) 추가 완료
# Batch 688 (1 docs) 추가 완료
# Batch 689 (1 docs) 추가 완료
# Batch 690 (1 docs) 추가 완료
# Batch 691 (1 docs) 추가 완료
# Batch 692 (1 docs) 추가 완료
# Batch 693 (1 docs) 추가 완료
# Batch 694 (1 docs) 추가 완료
# Batch 695 (1 docs) 추가 완료
# Batch 696 (1 docs) 추가 완료
# Batch 697 (1 docs) 추가 완료
# Batch 698 (1 docs) 추가 완료
# Batch 699 (1 docs) 추가 완료
# Batch 700 (1 docs) 추가 완료
# Batch 701 (1 docs) 추가 완료
# Batch 702 (1 docs) 추가 완료
# Batch 703 (1 docs) 추가 완료
# Batch 704 (1 docs) 추가 완료
# Batch 705 (1 docs) 추가 완료
# Batch 706 (1 docs) 추가 완료
# Batch 707 (1 docs) 추가 완료
# Batch 708 (1 docs) 추가 완료
# Batch 709 (1 docs) 추가 완료
# Batch 710 (1 docs) 추가 완료
# Batch 711 (1 docs) 추가 완료
# Batch 712 (1 docs) 추가 완료
# Batch 713 (1 docs) 추가 완료
# Batch 714 (1 docs) 추가 완료
# Batch 715 (1 docs) 추가 완료
# Batch 716 (1 docs) 추가 완료
# Batch 717 (1 docs) 추가 완료
# Batch 718 (1 docs) 추가 완료
# Batch 719 (1 docs) 추가 완료
# Batch 720 (1 docs) 추가 완료
# Batch 721 (1 docs) 추가 완료
# Batch 722 (1 docs) 추가 완료
# Batch 723 (1 docs) 추가 완료
# Batch 724 (1 docs) 추가 완료
# Batch 725 (1 docs) 추가 완료
# Batch 726 (1 docs) 추가 완료
# Batch 727 (1 docs) 추가 완료
# Batch 728 (1 docs) 추가 완료
# Batch 729 (1 docs) 추가 완료
# Batch 730 (1 docs) 추가 완료
# Batch 731 (1 docs) 추가 완료
# Batch 732 (1 docs) 추가 완료
# Batch 733 (1 docs) 추가 완료
# Batch 734 (1 docs) 추가 완료
# Batch 735 (1 docs) 추가 완료
# Batch 736 (1 docs) 추가 완료
# Batch 737 (1 docs) 추가 완료
# Batch 738 (1 docs) 추가 완료
# Batch 739 (1 docs) 추가 완료
# Batch 740 (1 docs) 추가 완료
# Batch 741 (1 docs) 추가 완료
# Batch 742 (1 docs) 추가 완료
# Batch 743 (1 docs) 추가 완료
# Batch 744 (1 docs) 추가 완료
# Batch 745 (1 docs) 추가 완료
# Batch 746 (1 docs) 추가 완료
# Batch 747 (1 docs) 추가 완료
# Batch 748 (1 docs) 추가 완료
# Batch 749 (1 docs) 추가 완료
# Batch 750 (1 docs) 추가 완료
# Batch 751 (1 docs) 추가 완료
# Batch 752 (1 docs) 추가 완료
# Batch 753 (1 docs) 추가 완료
# Batch 754 (1 docs) 추가 완료
# Batch 755 (1 docs) 추가 완료
# Batch 756 (1 docs) 추가 완료
# Batch 757 (1 docs) 추가 완료
# Batch 758 (1 docs) 추가 완료
# Batch 759 (1 docs) 추가 완료
# Batch 760 (1 docs) 추가 완료
# Batch 761 (1 docs) 추가 완료
# Batch 762 (1 docs) 추가 완료
# Batch 763 (1 docs) 추가 완료
# Batch 764 (1 docs) 추가 완료
# Batch 765 (1 docs) 추가 완료
# Batch 766 (1 docs) 추가 완료
# Batch 767 (1 docs) 추가 완료
# Batch 768 (1 docs) 추가 완료
# Batch 769 (1 docs) 추가 완료
# Batch 770 (1 docs) 추가 완료
# Batch 771 (1 docs) 추가 완료
# Batch 772 (1 docs) 추가 완료
# Batch 773 (1 docs) 추가 완료
# Batch 774 (1 docs) 추가 완료
# Batch 775 (1 docs) 추가 완료
# Batch 776 (1 docs) 추가 완료
# Batch 777 (1 docs) 추가 완료
# Batch 778 (1 docs) 추가 완료
# Batch 779 (1 docs) 추가 완료
# Batch 780 (1 docs) 추가 완료
# Batch 781 (1 docs) 추가 완료
# Batch 782 (1 docs) 추가 완료
# Batch 783 (1 docs) 추가 완료
# Batch 784 (1 docs) 추가 완료
# Batch 785 (1 docs) 추가 완료
# Batch 786 (1 docs) 추가 완료
# Batch 787 (1 docs) 추가 완료
# Batch 788 (1 docs) 추가 완료
# Batch 789 (1 docs) 추가 완료
# Batch 790 (1 docs) 추가 완료
# Batch 791 (1 docs) 추가 완료
# Batch 792 (1 docs) 추가 완료
# Batch 793 (1 docs) 추가 완료
# Batch 794 (1 docs) 추가 완료
# Batch 795 (1 docs) 추가 완료
# Batch 796 (1 docs) 추가 완료
# Batch 797 (1 docs) 추가 완료
# Batch 798 (1 docs) 추가 완료
# Batch 799 (1 docs) 추가 완료
# Batch 800 (1 docs) 추가 완료
# Batch 801 (1 docs) 추가 완료
# 모든 문서 임베딩 완료 및 저장 완료

# %%
from langchain_chroma import Chroma

DB_PATH = "../../../data/embedded/chroma_db"

persist_db = Chroma(
    persist_directory=DB_PATH,
    embedding_function=MyEmbeddings(),
    collection_name="samsung_quarterly_report",
)

print(len(persist_db.get()['ids']))
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 801

# %%
collection = persist_db._collection

# 벡터 꺼내기
results = collection.get(limit=5, include=["embeddings", "documents", "metadatas"])
print(results["embeddings"])
# Out:
# [[-2.45117188 -1.70996094 -2.4609375  ... -0.52050781 -0.51953125
#   -0.1661377 ]
#  [-3.34179688 -1.203125   -2.40429688 ...  0.31420898 -0.33349609
#    0.11706543]
#  [-1.08203125  3.65820312 -0.92578125 ... -2.5         0.90039062
#    2.52734375]
#  [ 3.52929688 -1.5625     -0.83203125 ...  0.36865234  2.390625
#    1.54882812]
#  [ 2.20703125 -1.40234375 -1.86328125 ...  0.39550781  1.234375
#    3.45898438]]

# %%
embedded_documents = my_embeddings.embed_documents("안녕하세요")

# %%
print(embedded_documents)
# Out:
# [[4.85546875, 1.6015625, 0.93408203125, -7.62109375, -0.353515625, -1.626953125, -2.572265625, 1.556640625, -0.58935546875, 2.693359375, -1.7802734375, -0.90283203125, 6.90625, -1.7021484375, -0.55859375, 2.5, -4.8203125, -0.96875, 3.1953125, 4.421875, -2.984375, 1.4443359375, 3.669921875, -0.23193359375, 2.09765625, 6.9609375, -5.9140625, -3.185546875, 0.0129547119140625, 2.45703125, -5.45703125, 1.5869140625, 0.609375, 2.796875, -2.544921875, 1.736328125, -2.734375, 0.26806640625, 2.279296875, -1.423828125, -1.5634765625, 0.89794921875, 1.5634765625, 0.33740234375, -1.388671875, -2.623046875, -3.0859375, -1.2333984375, 0.630859375, 1.2041015625, -0.22119140625, -4.01953125, -3.765625, -1.8115234375, -0.72314453125, -0.348388671875, -0.6416015625, -2.318359375, -3.234375, -1.4189453125, -5.4921875, 3.525390625, -1.98046875, -1.6259765625, 1.8681640625, 1.0166015625, 1.4736328125, -2.1484375, 1.048828125, -1.7939453125, 0.5263671875, -1.1591796875, 2.939453125, 1.3212890625, -0.57470703125, 3.478515625, -4.60546875, -2.400390625, 0.67431640625, 3.982421875, -1.6396484375, 1.9794921875, -0.697265625, -2.681640625, 0.82470703125, -2.236328125, 2.1015625, -1.263671875, -0.9189453125, -0.275146484375, 2.591796875, -1.630859375, 0.4453125, 0.740234375, -1.578125, 0.07318115234375, -1.37890625, 0.28369140625, -2.994140625, -0.373779296875, 2.240234375, 2.439453125, 0.85693359375, 1.4697265625, 1.6171875, -0.2318115234375, -3.80859375, 0.129638671875, -2.87890625, -2.474609375, 1.0576171875, -0.041290283203125, 4.84765625, 3.283203125, 0.6484375, -3.271484375, -1.375, 0.93798828125, -2.357421875, 2.501953125, 0.982421875, 1.08984375, -2.279296875, -1.130859375, 1.3349609375, -3.650390625, -2.984375, 3.76171875, 2.349609375, -0.68798828125, 0.85595703125, -2.37109375, 0.96484375, -2.783203125, 2.7421875, -1.9716796875, 0.755859375, -0.52294921875, -1.5791015625, 0.2509765625, 0.401611328125, 2.328125, -0.428466796875, -0.136474609375, -0.77587890625, 3.96484375, 0.77734375, 1.5068359375, -0.037841796875, 0.529296875, -0.27880859375, -0.487060546875, -1.525390625, -3.16796875, -2.8203125, -2.146484375, -1.9462890625, 2.53125, 3.77734375, 0.62109375, 0.39697265625, 1.26171875, 1.640625, -1.1083984375, 2.744140625, -0.457763671875, 1.35546875, -0.82861328125, 4.4375, 2.60546875, 2.064453125, -0.576171875, -3.013671875, 0.6982421875, 0.393798828125, -3.0390625, -2.888671875, -2.99609375, 0.88037109375, 1.509765625, -0.38818359375, -0.34375, 2.091796875, 3.884765625, -0.546875, 2.294921875, 1.0302734375, -1.146484375, -1.302734375, 1.5869140625, 2.16015625, -0.30712890625, -1.2685546875, 1.763671875, 1.4140625, -0.209228515625, 0.409912109375, 1.6708984375, 2.201171875, -2.109375, 5.4765625, -1.4755859375, 1.859375, 1.9169921875, -0.221435546875, 0.3330078125, -2.0546875, 2.640625, 0.203857421875, -1.3408203125, 0.69775390625, -0.398681640625, 0.3232421875, 2.8359375, -0.55224609375, -0.8798828125, 1.404296875, -2.958984375, -2.224609375, 0.826171875, 3.3125, -0.59375, -0.0081787109375, 2.91015625, 0.297119140625, -5.1796875, 2.52734375, -0.35693359375, 2.173828125, -2.876953125, 2.759765625, -4.5390625, -1.1875, -1.3095703125, -1.3330078125, -1.546875, 1.826171875, -2.849609375, -0.11376953125, 3.3203125, 1.3974609375, -2.30859375, 0.49755859375, -1.822265625, 1.01953125, -1.5078125, 1.1845703125, -4.359375, 1.4521484375, -2.728515625, -0.7783203125, 0.5, -0.81298828125, -1.37109375, -1.041015625, -2.82421875, 0.2392578125, -0.798828125, 0.896484375, 1.7958984375, -0.9794921875, -1.6201171875, -0.0712890625, 2.625, -2.3046875, 0.9658203125, -1.943359375, -4.3828125, 1.693359375, 0.369140625, 0.12841796875, -2.94921875, -1.0078125, -1.05078125, -0.3798828125, 2.265625, -1.56640625, -0.85791015625, -2.7265625, 1.908203125, -2.544921875, -2.341796875, 3.9375, -0.822265625, 0.7724609375, 0.84130859375, -0.0021762847900390625, 3.517578125, -2.138671875, 1.095703125, 0.8701171875, 2.19140625, 0.994140625, 1.7744140625, -0.134765625, 1.080078125 ...
